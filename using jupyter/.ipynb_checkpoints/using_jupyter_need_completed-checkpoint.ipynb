# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# The ships *hung in the sky* in much the same way that **bricks don’t.**<sup>1</sup><sub>QUOTE</sub>

# %% [markdown]
# [SP2273 Website](https://sps.nus.edu.sg/sp2273)

# %% [markdown]
# ![](https://nus.edu.sg/images/default-source/base/logo.png)

# %% [markdown]
# ![Screenshot 2024-01-07 000416.png](attachment:98d4e078-157b-4d99-b0d8-7e792785e3f0.png)

# %% [markdown]
# Favorite fruits:
# 1. Apple
# 2. Banana
# 3. Pear
#    - juicy
#    - tasty
#    - pear
#    - green
