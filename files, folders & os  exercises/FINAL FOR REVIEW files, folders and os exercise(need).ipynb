# %% [markdown]
# **Task 1 and 2**

# %%
import os
import glob
import shutil

# %%
glob.glob('*')
# Out:
# ['files, folders and os exercise 2.0.ipynb',
#  'files,_folders_&_os_(need)_exercises.ipynb',
#  'os-collaboration-exercise-data']

# %%
def rename_my_file(old_file_name):
    date_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    
    date_split = old_file_name.split("-")
    text_date = date_split[0]
    number_date = date_dict[text_date]
    new_file_name = f"{number_date}-{date_split[1].replace("_", "-")}"
    return new_file_name

# %%
rename_my_file('oct-08_singapore.txt')
# Out:
# '10-08-singapore.txt'

# %% [markdown]
# **Task 3**

# %%
file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

# %%
for file in file_list:
    new_file_name = rename_my_file(file)
    print(f"{file}---->{new_file_name}")
# Out:
# oct-08_singapore.txt---->10-08-singapore.txt
# jul-10_cairo.txt---->07-10-cairo.txt
# may-15_dhaka.txt---->05-15-dhaka.txt
# may-13_cairo.txt---->05-13-cairo.txt
# oct-21_cairo.txt---->10-21-cairo.txt
# jan-10_singapore.txt---->01-10-singapore.txt
# jun-20_tokyo.txt---->06-20-tokyo.txt
# aug-06_jakarta.txt---->08-06-jakarta.txt
# dec-21_karachi.txt---->12-21-karachi.txt
# jan-01_tokyo.txt---->01-01-tokyo.txt

# %% [markdown]
# **Task 4**

# %% [markdown]
# I'm making a new folder to store all of the text files.

# %%
os.mkdir("os-collaboration-text-files")

# %%
glob.glob(os.path.join(".", "os-collaboration-exercise-data", "*.txt"))
# Out:
# ['.\\os-collaboration-exercise-data\\apr-01_melbourne.txt',
#  '.\\os-collaboration-exercise-data\\apr-01_shanghai.txt',
#  '.\\os-collaboration-exercise-data\\apr-01_singapore.txt',
#  '.\\os-collaboration-exercise-data\\apr-02_cairo.txt',
#  '.\\os-collaboration-exercise-data\\apr-02_jakarta.txt',
#  '.\\os-collaboration-exercise-data\\apr-02_karachi.txt',
#  '.\\os-collaboration-exercise-data\\apr-02_shanghai.txt',
#  '.\\os-collaboration-exercise-data\\apr-03_manila.txt',
#  '.\\os-collaboration-exercise-data\\apr-03_osaka.txt',
#  '.\\os-collaboration-exercise-data\\apr-03_singapore.txt',
#  '.\\os-collaboration-exercise-data\\apr-03_tokyo.txt',
#  '.\\os-collaboration-exercise-data\\apr-04_manila.txt',
#  '.\\os-collaboration-exercise-data\\apr-04_melbourne.txt',
#  '.\\os-collaboration-exercise-data\\apr-04_shanghai.txt',
#  '.\\os-collaboration-exercise-data\\apr-04_singapore.txt',
#  '.\\os-collaboration-exercise-data\\apr-05_karachi.txt',
# ...

# %%
text_files = glob.glob(os.path.join(".", "os-collaboration-exercise-data", "*.txt"))
text_files_destination = os.path.join(".", "os-collaboration-text-files")
for file in text_files:
    shutil.copy(file, text_files_destination)

# %% [markdown]
# - It worked!

# %% [markdown]
# ![Screenshot 2024-02-22 175619.png](attachment:1038523a-073b-4c99-9bfc-9afb27635ac4.png)

# %%
text_files = glob.glob(os.path.join(".", "os-collaboration-text-files", "*.txt"))
print(text_files)
# Out:
# ['.\\os-collaboration-text-files\\apr-01_melbourne.txt', '.\\os-collaboration-text-files\\apr-01_shanghai.txt', '.\\os-collaboration-text-files\\apr-01_singapore.txt', '.\\os-collaboration-text-files\\apr-02_cairo.txt', '.\\os-collaboration-text-files\\apr-02_jakarta.txt', '.\\os-collaboration-text-files\\apr-02_karachi.txt', '.\\os-collaboration-text-files\\apr-02_shanghai.txt', '.\\os-collaboration-text-files\\apr-03_manila.txt', '.\\os-collaboration-text-files\\apr-03_osaka.txt', '.\\os-collaboration-text-files\\apr-03_singapore.txt', '.\\os-collaboration-text-files\\apr-03_tokyo.txt', '.\\os-collaboration-text-files\\apr-04_manila.txt', '.\\os-collaboration-text-files\\apr-04_melbourne.txt', '.\\os-collaboration-text-files\\apr-04_shanghai.txt', '.\\os-collaboration-text-files\\apr-04_singapore.txt', '.\\os-collaboration-text-files\\apr-05_karachi.txt', '.\\os-collaboration-text-files\\apr-05_melbourne.txt', '.\\os-collaboration-text-files\\apr-05_shanghai.txt', '.\\os-collaborat
# ...

# %%
text_files = glob.glob(os.path.join(".", "os-collaboration-text-files", "*.txt"))
for file in text_files: 
    file_name = file.split(os.path.sep)[-1]
    folder_name = file.split(os.path.sep)[-2]
    try: 
        new_file_name = os.path.join(folder_name, rename_my_file(file_name))
        os.rename(file, new_file_name)
        print(f"{new_file_name} has been renamed")
    except KeyError:
        




print(f"{new_file_name} has already been renamed!")
# Out:
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# os-collaboration-text-files\04-01-melbourne.txt has already been renamed!
# ...

# %% [markdown]
# - It worked!

# %% [markdown]
# ![Screenshot 2024-02-22 175619.png](attachment:9c229a2a-fafc-48cb-a174-a031f336dc3b.png)

# %% [markdown]
# **Task 5**

# %%
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']

# %%
os.mkdir("Cities")

# %%
for city in city_list:
    city_path = os.path.join("Cities", city)
    print(f"Creating {city_path}")
    os.mkdir(city_path)
# Out:
# Creating Cities\Cairo
# Creating Cities\Dhaka
# Creating Cities\Jakarta
# Creating Cities\Karachi
# Creating Cities\Manila
# Creating Cities\Melbourne
# Creating Cities\Osaka
# Creating Cities\Shanghai
# Creating Cities\Singapore
# Creating Cities\Tokyo

# %% [markdown]
# **Task 6**

# %%
cairo_files = glob.glob(os.path.join(".", "os-collaboration-text-files", "*cairo.txt"))
print(cairo_files)
# Out:
# ['.\\os-collaboration-text-files\\01-02-cairo.txt', '.\\os-collaboration-text-files\\01-03-cairo.txt', '.\\os-collaboration-text-files\\01-04-cairo.txt', '.\\os-collaboration-text-files\\01-05-cairo.txt', '.\\os-collaboration-text-files\\01-07-cairo.txt', '.\\os-collaboration-text-files\\01-08-cairo.txt', '.\\os-collaboration-text-files\\01-09-cairo.txt', '.\\os-collaboration-text-files\\01-11-cairo.txt', '.\\os-collaboration-text-files\\01-12-cairo.txt', '.\\os-collaboration-text-files\\01-13-cairo.txt', '.\\os-collaboration-text-files\\01-15-cairo.txt', '.\\os-collaboration-text-files\\01-16-cairo.txt', '.\\os-collaboration-text-files\\01-19-cairo.txt', '.\\os-collaboration-text-files\\01-20-cairo.txt', '.\\os-collaboration-text-files\\01-21-cairo.txt', '.\\os-collaboration-text-files\\01-23-cairo.txt', '.\\os-collaboration-text-files\\01-27-cairo.txt', '.\\os-collaboration-text-files\\01-30-cairo.txt', '.\\os-collaboration-text-files\\02-10-cairo.txt', '.\\os-collaboration-text-fi
# ...

# %%
for file in cairo_files:
    destination_folder = os.path.join(".", "Cities", "Cairo")
    shutil.copy(file, destination_folder)

# %% [markdown]
# - It worked!

# %% [markdown]
# ![Screenshot 2024-02-22 183621.png](attachment:074702f5-9dff-42a1-a24b-dbb987a06203.png)

# %%
for city in city_list: 
    folder_empty_check = glob.glob(os.path.join(".", "Cities", city, "*"))
    if folder_empty_check == []:
        city_files = cairo_files = glob.glob(os.path.join(".", "os-collaboration-text-files", f"*{city.lower()}.txt"))
        destination_folder = os.path.join(".", "Cities", city)
        for file in city_files:
            shutil.copy(file, destination_folder)

    else: 
        print(f"{city} files have already been copied over!")
# Out:
# Cairo files have already been copied over!
# Dhaka files have already been copied over!
# Jakarta files have already been copied over!
# Karachi files have already been copied over!
# Manila files have already been copied over!
# Melbourne files have already been copied over!
# Osaka files have already been copied over!
# Shanghai files have already been copied over!
# Singapore files have already been copied over!
# Tokyo files have already been copied over!

# %% [markdown]
# -It worked!

# %% [markdown]
# ![Screenshot 2024-02-22 184405.png](attachment:aa2a7090-858e-4f42-bb70-7a1f16979c12.png)
