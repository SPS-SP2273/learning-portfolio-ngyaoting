# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Files, Folders & OS (Need) Exercises</span></div>

# %%
import os
import glob
import shutil

# %%
glob.glob('*')
# Out:
# ['files,_folders_&_os_(need)_exercises.ipynb',
#  'os-collaboration-exercise-data',
#  'os-collaboration-text-files']

# %% [markdown]
# - I copied all the text files to a new folder, which I named os-collaboration-text-files

# %%
text_files = glob.glob("os-collaboration-exercise-data/**/*.txt", recursive = True)
for file in text_files:
    path_to_destination = r"C:\Users\User\OneDrive\Documents\NUS\Y1\Sem2\SP2273\learning-portfolio-ngyaoting\files, folders & os  exercises\os-collaboration-text-files"
    shutil.copy(file, path_to_destination)

# %%
print(text_files)
# Out:
# ['os-collaboration-exercise-data\\apr-01_melbourne.txt', 'os-collaboration-exercise-data\\apr-01_shanghai.txt', 'os-collaboration-exercise-data\\apr-01_singapore.txt', 'os-collaboration-exercise-data\\apr-02_cairo.txt', 'os-collaboration-exercise-data\\apr-02_jakarta.txt', 'os-collaboration-exercise-data\\apr-02_karachi.txt', 'os-collaboration-exercise-data\\apr-02_shanghai.txt', 'os-collaboration-exercise-data\\apr-03_manila.txt', 'os-collaboration-exercise-data\\apr-03_osaka.txt', 'os-collaboration-exercise-data\\apr-03_singapore.txt', 'os-collaboration-exercise-data\\apr-03_tokyo.txt', 'os-collaboration-exercise-data\\apr-04_manila.txt', 'os-collaboration-exercise-data\\apr-04_melbourne.txt', 'os-collaboration-exercise-data\\apr-04_shanghai.txt', 'os-collaboration-exercise-data\\apr-04_singapore.txt', 'os-collaboration-exercise-data\\apr-05_karachi.txt', 'os-collaboration-exercise-data\\apr-05_melbourne.txt', 'os-collaboration-exercise-data\\apr-05_shanghai.txt', 'os-collaboration
# ...

# %%
def rename_my_file(old_file_name):
    date_dict = {
    'jan': '01', 'feb': '02', 'mar': '03',
    'apr': '04', 'may': '05', 'jun': '06',
    'jul': '07', 'aug': '08', 'sep': '09',
    'oct': '10', 'nov': '11', 'dec': '12'
    }
    
    date_split = old_file_name.split("-")
    text_date = date_split[0]
    number_date = date_dict[text_date]
    new_file_name = "os-collaboration-text-files\\" + number_date + "-" + date_split[1]
    return new_file_name

# %%
data_file_list = ['oct-08_singapore.txt', 'jul-10_cairo.txt', 'may-15_dhaka.txt',
 'may-13_cairo.txt', 'oct-21_cairo.txt', 'jan-10_singapore.txt',
 'jun-20_tokyo.txt', 'aug-06_jakarta.txt', 'dec-21_karachi.txt',
 'jan-01_tokyo.txt']

for previous_file_name in data_file_list:
    latest_file_name = rename_my_file(previous_file_name)
    print(f"{previous_file_name} ----> {latest_file_name}")
# Out:
# oct-08_singapore.txt ----> os-collaboration-text-files\10-08_singapore.txt
# jul-10_cairo.txt ----> os-collaboration-text-files\07-10_cairo.txt
# may-15_dhaka.txt ----> os-collaboration-text-files\05-15_dhaka.txt
# may-13_cairo.txt ----> os-collaboration-text-files\05-13_cairo.txt
# oct-21_cairo.txt ----> os-collaboration-text-files\10-21_cairo.txt
# jan-10_singapore.txt ----> os-collaboration-text-files\01-10_singapore.txt
# jun-20_tokyo.txt ----> os-collaboration-text-files\06-20_tokyo.txt
# aug-06_jakarta.txt ----> os-collaboration-text-files\08-06_jakarta.txt
# dec-21_karachi.txt ----> os-collaboration-text-files\12-21_karachi.txt
# jan-01_tokyo.txt ----> os-collaboration-text-files\01-01_tokyo.txt

# %%
for file in text_files:
    previous_file_name = file.split("\\")[-1]
    latest_file_name = rename_my_file(previous_file_name)
    print(latest_file_name)
    os.rename(r"C:\Users\User\OneDrive\Documents\NUS\Y1\Sem2\SP2273\learning-portfolio-ngyaoting\files, folders & os  exercises\os-collaboration-text-files\\" + previous_file_name, latest_file_name)
# Out:
# ['apr', '01_melbourne.txt']
# 04
# os-collaboration-text-files\04-01_melbourne.txt
# ['apr', '01_shanghai.txt']
# 04
# os-collaboration-text-files\04-01_shanghai.txt
# ['apr', '01_singapore.txt']
# 04
# os-collaboration-text-files\04-01_singapore.txt
# ['apr', '02_cairo.txt']
# 04
# os-collaboration-text-files\04-02_cairo.txt
# ['apr', '02_jakarta.txt']
# 04
# os-collaboration-text-files\04-02_jakarta.txt
# ['apr', '02_karachi.txt']
# 04
# os-collaboration-text-files\04-02_karachi.txt
# ['apr', '02_shanghai.txt']
# 04
# os-collaboration-text-files\04-02_shanghai.txt
# ['apr', '03_manila.txt']
# 04
# os-collaboration-text-files\04-03_manila.txt
# ['apr', '03_osaka.txt']
# 04
# os-collaboration-text-files\04-03_osaka.txt
# ['apr', '03_singapore.txt']
# 04
# os-collaboration-text-files\04-03_singapore.txt
# ['apr', '03_tokyo.txt']
# 04
# os-collaboration-text-files\04-03_tokyo.txt
# ['apr', '04_manila.txt']
# 04
# os-collaboration-text-files\04-04_manila.txt
# ...

# %% [markdown]
# ![Screenshot%202024-02-08%20170152.png](attachment:Screenshot%202024-02-08%20170152.png)

# %% [markdown]
# - It worked!

# %%
city_list = ['Cairo', 'Dhaka', 'Jakarta', 'Karachi', 'Manila',
 'Melbourne', 'Osaka', 'Shanghai', 'Singapore', 'Tokyo']
try:
    os.mkdir("Cities")
except FileExistsError:
    print("alr exists")
    
for city in city_list: 
    path = os.path.join("Cities", city)
    print(path)
    os.mkdir(path)
# Out:
# alr exists
# Cities\Cairo
# Cities\Dhaka
# Cities\Jakarta
# Cities\Karachi
# Cities\Manila
# Cities\Melbourne
# Cities\Osaka
# Cities\Shanghai
# Cities\Singapore
# Cities\Tokyo

# %% [markdown]
# ![image_2024-02-08_175253492.png](attachment:image_2024-02-08_175253492.png)

# %% [markdown]
# - It worked!

# %%
for city in city_list:
    city_text_files = glob.glob(f"*text-files/**/*{city}.txt", recursive = True)
    print(city_text_files)
    for file in city_text_files:
        path_to_destination = r"C:\Users\User\OneDrive\Documents\NUS\Y1\Sem2\SP2273\learning-portfolio-ngyaoting\files, folders & os  exercises\Cities\\" + city
        shutil.copy(file, path_to_destination)
# Out:
# ['os-collaboration-text-files\\01-02_cairo.txt', 'os-collaboration-text-files\\01-03_cairo.txt', 'os-collaboration-text-files\\01-04_cairo.txt', 'os-collaboration-text-files\\01-05_cairo.txt', 'os-collaboration-text-files\\01-07_cairo.txt', 'os-collaboration-text-files\\01-08_cairo.txt', 'os-collaboration-text-files\\01-09_cairo.txt', 'os-collaboration-text-files\\01-11_cairo.txt', 'os-collaboration-text-files\\01-12_cairo.txt', 'os-collaboration-text-files\\01-13_cairo.txt', 'os-collaboration-text-files\\01-15_cairo.txt', 'os-collaboration-text-files\\01-16_cairo.txt', 'os-collaboration-text-files\\01-19_cairo.txt', 'os-collaboration-text-files\\01-20_cairo.txt', 'os-collaboration-text-files\\01-21_cairo.txt', 'os-collaboration-text-files\\01-23_cairo.txt', 'os-collaboration-text-files\\01-27_cairo.txt', 'os-collaboration-text-files\\01-30_cairo.txt', 'os-collaboration-text-files\\02-10_cairo.txt', 'os-collaboration-text-files\\02-17_cairo.txt', 'os-collaboration-text-files\\02-20_c
# ...

# %% [markdown]
# ![image_2024-02-08_181210323.png](attachment:image_2024-02-08_181210323.png)

# %% [markdown]
# - It worked!
